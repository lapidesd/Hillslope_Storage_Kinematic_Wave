# %%
import os
import math
from sklearn.metrics import mean_squared_error
import pandas as pd
import matplotlib.pyplot as plt

# %%
filepath = "USER_PATH_TO_TXT_FILES/"                           # user input location of downloaded txt files containing hydrograph data

for file in os.listdir(filepath):                              # for loop prints a hydrograph for each downloaded file
    if file.endswith(".hydrograph.txt"):
        print(os.path.join(file))
        filename = filepath+str(file)                          # builds file name
        if str(file)[0]=='n':                                  # if loop removes excess characters and alters strings to correct a values
            m = 0
            n = 0
            for c in range(len(str(file))):
                if str(file)[c]=='_' and m==0:
                    m=c
                elif str(file)[c]=='_' and n==0:
                    n=c
            if str(file)[m+1:n]=='0':
                aval = '0'
            else:
                aval = '-'+(str(file)[m+1:n])
        else:
            m = 0
            for c in range(len(str(file))):
                if str(file)[c]=='_' and m==0:
                    m=c
            aval = (str(file)[:m])       
        filer = pd.read_csv(filename, sep=' ').reset_index().set_index('25')   # imports txt data into pandas dataframe                   
        plt.plot(filer['0.0'])
        plt.xlabel('time (min)')
        plt.ylabel('Q (m$^3$/s)')
        plt.show()
# Out:
# 0.00001_5slope.manning.0.001.hydrograph.txt
# 0.001_5slope.manning.7e-5.hydrograph.txt
# 0.1_5slope.manning.0.001.hydrograph.txt
# negative_0.00001_5slope.manning.7e-5.hydrograph.txt
# 0_5slope.manning.0.001.hydrograph.txt
# negative_0.05_5slope.manning.0.001.hydrograph.txt
# 0.00001_5slope.manning.7e-5.hydrograph.txt
# negative_0.02_5slope.manning.7e-5.hydrograph.txt
# negative_0.005_5slope.manning.7e-5.hydrograph.txt
# 0_5slope.manning.7e-5.hydrograph.txt
# 0.0001_5slope.manning.0.001.hydrograph.txt
# 0.02_5slope.manning.0.001.hydrograph.txt
# 0.0005_5slope.manning.7e-5.hydrograph.txt
# negative_0.005_5slope.manning.0.001.hydrograph.txt
# negative_0.05_5slope.manning.7e-5.hydrograph.txt
# 0.02_5slope.manning.0.02.hydrograph.txt
# negative_0.0001_5slope.manning.0.001.hydrograph.txt
# 0.005_5slope.manning.0.001.hydrograph.txt
# 0.01_5slope.manning.0.001.hydrograph.txt
# negative_0.0005_5slope.manning.7e-5.hydrograph.txt
# 0.01_5slope.manning.7e-5.hydrograph.txt
# ...
